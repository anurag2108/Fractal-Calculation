# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (75.1.0)
# Collecting jedi>=0.16 (from ipython->ipython-autotime)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.13)
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.7 MB/s eta 0:00:00
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.2 jedi-0.19.1
# time: 459 µs (started: 2024-11-10 17:40:07 +00:00)

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (24.1)
# Downloading faiss_cpu-1.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 19.2 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.9.0
# time: 17.5 s (started: 2024-11-10 17:40:07 +00:00)

# %%
import numpy as np
import requests
import io

# URL of the Simple English word vectors
url = "https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.simple.vec"

print("Downloading word vectors...")
response = requests.get(url)
content = io.StringIO(response.content.decode('utf-8'))

word_embeddings = {}

num_words, vector_size = map(int, next(content).split())

for line in content:
    tokens = line.rstrip().split(' ')
    word = tokens[0]
    vector = np.array(tokens[1:], dtype=float)
    word_embeddings[word] = vector

print(f"Total number of words: {len(word_embeddings)}")
print(f"Dimension of each word vector: {vector_size}")

# Example: Print the first 5 words and their vector dimensions
for word in list(word_embeddings.keys())[:5]:
    print(f"{word}: {word_embeddings[word].shape}")
# Out:
# Downloading word vectors...
# Total number of words: 111051
# Dimension of each word vector: 300
# </s>: (300,)
# .: (300,)
# ,: (300,)
# the: (300,)
# of: (300,)
# time: 19.5 s (started: 2024-11-10 17:40:24 +00:00)

# %%
#cluster analysis for each word, based on number of clusters considered for each word we have a different fractal value.


import numpy as np
import faiss
import matplotlib.pyplot as plt
import requests
import io
from collections import defaultdict


print(f"Total number of words: {len(word_embeddings)}")
print(f"Dimension of each word vector: {vector_size}")

# Create FAISS index
print("Creating FAISS index...")
index = faiss.IndexFlatL2(vector_size)
index.add(np.array(list(word_embeddings.values())))

def cluster_fractal_analysis(data, max_clusters, min_clusters=2):
    n_samples, n_features = data.shape
    data = data.astype(np.float32)

    results = []

    for k in range(min_clusters, max_clusters + 1):
        kmeans = faiss.Kmeans(d=n_features, k=k, niter=300, verbose=False)
        kmeans.train(data)
        _, labels = kmeans.index.search(data, 1)

        unique, counts = np.unique(labels, return_counts=True)
        cluster_sizes = counts[counts > 0]

        cluster_fractal_dims = np.log(cluster_sizes) / np.log(k)

        log_n = np.log(k)
        log_m = np.log(np.sum(cluster_sizes * np.log(cluster_sizes)))
        total_dimension = log_m / log_n if log_n != 0 else np.nan

        results.append({
            'num_clusters': k,
            'cluster_sizes': cluster_sizes,
            'cluster_fractal_dims': cluster_fractal_dims,
            'total_fractal_dim': total_dimension
        })

    return results

def cluster_fractal_dimension(data, max_clusters, min_clusters=2):
    n_samples, n_features = data.shape
    data = data.astype(np.float32)

    dimensions = []
    cluster_counts = range(min_clusters, max_clusters + 1)

    for k in cluster_counts:
        kmeans = faiss.Kmeans(d=n_features, k=k, niter=300, verbose=False)
        kmeans.train(data)
        _, labels = kmeans.index.search(data, 1)

        unique, counts = np.unique(labels, return_counts=True)
        cluster_sizes = counts[counts > 0]

        log_n = np.log(k)
        log_m = np.log(np.sum(cluster_sizes * np.log(cluster_sizes)))
        dimension = log_m / log_n if log_n != 0 else np.nan

        dimensions.append(dimension)

    return cluster_counts, dimensions

def progressive_fractal_dimension(data, max_clusters, min_clusters=2):
    cluster_counts, dimensions = cluster_fractal_dimension(data, max_clusters, min_clusters)
    return cluster_counts, dimensions

# List of words to analyze
words_to_analyze = [
    "Set", "Run", "Go", "Take", "Get", "Make", "Put", "Stand", "Hold", "Turn",
    "Break", "Fall", "Cut", "Pass", "Bring", "Do", "Catch", "Draw", "Leave", "Keep",
    "Pay", "Build", "Lead", "Raise", "Move", "Close", "Meet", "Reach", "Send", "Drive",
    "Throw", "Read", "Walk"
]

fractal_dimensions = defaultdict(list)

for word in words_to_analyze:
    if word.lower() in word_embeddings:
        print(f"\nAnalyzing word: {word}")

        # Find 10,000 closest words
        query_vector = word_embeddings[word.lower()].reshape(1, -1)
        _, indices = index.search(query_vector, 10000)

        closest_words_embeddings = np.array([list(word_embeddings.values())[i] for i in indices[0]])

        max_clusters = min(50, 10000 // 2)
        cluster_counts, progressive_dims = progressive_fractal_dimension(closest_words_embeddings, max_clusters)

        # Store fractal dimensions for each cluster count
        for count, dim in zip(cluster_counts, progressive_dims):
            fractal_dimensions[count].append(dim)

        # Plot results
        plt.figure(figsize=(12, 6))
        plt.plot(cluster_counts, progressive_dims, 'bo-')
        plt.xscale('log')
        plt.xlabel('Number of Clusters')
        plt.ylabel('Estimated Fractal Dimension')
        plt.title(f'Progressive Fractal Dimension Analysis for "{word}"')
        plt.grid(True)

        final_dim = progressive_dims[-1]
        plt.axhline(y=final_dim, color='r', linestyle='--', label=f'Final Dimension: {final_dim:.2f}')
        plt.legend()

        plt.savefig(f'{word}_fractal_dimension.png')
        plt.close()

        results = cluster_fractal_analysis(closest_words_embeddings, max_clusters)

        # Print results
        for result in results:
            print(f"\nNumber of clusters: {result['num_clusters']}")
            print(f"Total fractal dimension: {result['total_fractal_dim']:.4f}")
    else:
        print(f"\nWord '{word}' not found in the embeddings.")

# Plot average fractal dimensions
plt.figure(figsize=(12, 6))
avg_dims = [np.mean(fractal_dimensions[count]) for count in sorted(fractal_dimensions.keys())]
plt.plot(sorted(fractal_dimensions.keys()), avg_dims, 'ro-')
plt.xscale('log')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Estimated Fractal Dimension')
plt.title('Average Progressive Fractal Dimension Analysis')
plt.grid(True)

final_avg_dim = avg_dims[-1]
plt.axhline(y=final_avg_dim, color='b', linestyle='--', label=f'Final Average Dimension: {final_avg_dim:.2f}')
plt.legend()

plt.savefig('average_fractal_dimension.png')
plt.close()
# Out:
# Total number of words: 111051
# Dimension of each word vector: 300
# Creating FAISS index...
#
# Analyzing word: Set
#
# Number of clusters: 2
# Total fractal dimension: 16.3781
#
# Number of clusters: 3
# Total fractal dimension: 10.2891
#
# Number of clusters: 4
# Total fractal dimension: 8.1302
#
# Number of clusters: 5
# Total fractal dimension: 6.9851
#
# Number of clusters: 6
# Total fractal dimension: 6.2603
#
# Number of clusters: 7
# Total fractal dimension: 5.7535
#
# Number of clusters: 8
# Total fractal dimension: 5.3763
#
# Number of clusters: 9
# Total fractal dimension: 5.0875
#
# Number of clusters: 10
# Total fractal dimension: 4.8706
#
# Number of clusters: 11
# Total fractal dimension: 4.6627
#
# Number of clusters: 12
# Total fractal dimension: 4.4849
#
# Number of clusters: 13
# Total fractal dimension: 4.3306
#
# Number of clusters: 14
# Total fractal dimension: 4.2286
#
# Number of clusters: 15
# Total fractal dimension: 4.0972
#
# Number of clusters: 16
# Total fractal dimension: 4.0128
#
# Number of clusters: 17
# Total fractal dimension: 3.9209
#
# Number of clusters: 18
# Total fractal dimension: 3.8353
#
# Number of clusters: 19
# Total fractal dimension: 3.7571
#
# Number of clusters: 20
# Total fractal dimension: 3.6903
#
# Number of clusters: 21
# Total fractal dimension: 3.6373
#
# Number of clusters: 22
# Total fractal dimension: 3.5748
#
# Number of clusters: 23
# Total fractal dimension: 3.5202
#
# Number of clusters: 24
# Total fractal dimension: 3.4966
#
# Number of clusters: 25
# Total fractal dimension: 3.4313
#
# Number of clusters: 26
# Total fractal dimension: 3.3837
#
# Number of clusters: 27
# Total fractal dimension: 3.3467
#
# Number of clusters: 28
# Total fractal dimension: 3.3001
#
# Number of clusters: 29
# Total fractal dimension: 3.2647
#
# Number of clusters: 30
# Total fractal dimension: 3.2314
#
# Number of clusters: 31
# Total fractal dimension: 3.2017
#
# Number of clusters: 32
# Total fractal dimension: 3.1675
#
# Number of clusters: 33
# Total fractal dimension: 3.1416
#
# Number of clusters: 34
# Total fractal dimension: 3.1101
#
# Number of clusters: 35
# Total fractal dimension: 3.0975
#
# Number of clusters: 36
# Total fractal dimension: 3.0602
#
# Number of clusters: 37
# Total fractal dimension: 3.0489
#
# Number of clusters: 38
# Total fractal dimension: 3.0107
#
# Number of clusters: 39
# Total fractal dimension: 2.9904
#
# Number of clusters: 40
# Total fractal dimension: 2.9697
#
# Number of clusters: 41
# Total fractal dimension: 2.9488
#
# Number of clusters: 42
# Total fractal dimension: 2.9273
#
# Number of clusters: 43
# Total fractal dimension: 2.9093
#
# Number of clusters: 44
# Total fractal dimension: 2.8913
#
# Number of clusters: 45
# Total fractal dimension: 2.8735
#
# Number of clusters: 46
# Total fractal dimension: 2.8567
#
# Number of clusters: 47
# Total fractal dimension: 2.8395
#
# Number of clusters: 48
# Total fractal dimension: 2.8230
#
# Number of clusters: 49
# Total fractal dimension: 2.8073
#
# Number of clusters: 50
# Total fractal dimension: 2.7921
#
# Analyzing word: Run
#
# Number of clusters: 2
# Total fractal dimension: 16.3787
#
# Number of clusters: 3
# Total fractal dimension: 10.2892
#
# Number of clusters: 4
# Total fractal dimension: 8.1298
#
# Number of clusters: 5
# Total fractal dimension: 6.9852
#
# Number of clusters: 6
# Total fractal dimension: 6.2625
#
# Number of clusters: 7
# Total fractal dimension: 5.7639
#
# Number of clusters: 8
# Total fractal dimension: 5.3767
#
# Number of clusters: 9
# Total fractal dimension: 5.0802
#
# Number of clusters: 10
# Total fractal dimension: 4.8414
#
# Number of clusters: 11
# Total fractal dimension: 4.6630
#
# Number of clusters: 12
# Total fractal dimension: 4.4797
#
# Number of clusters: 13
# Total fractal dimension: 4.3386
#
# Number of clusters: 14
# Total fractal dimension: 4.2348
#
# Number of clusters: 15
# Total fractal dimension: 4.0939
#
# Number of clusters: 16
# Total fractal dimension: 4.0113
#
# Number of clusters: 17
# Total fractal dimension: 3.9287
#
# Number of clusters: 18
# Total fractal dimension: 3.8292
#
# Number of clusters: 19
# Total fractal dimension: 3.7530
#
# Number of clusters: 20
# Total fractal dimension: 3.6913
#
# Number of clusters: 21
# Total fractal dimension: 3.6296
#
# Number of clusters: 22
# Total fractal dimension: 3.5797
#
# Number of clusters: 23
# Total fractal dimension: 3.5257
#
# Number of clusters: 24
# Total fractal dimension: 3.4797
#
# Number of clusters: 25
# Total fractal dimension: 3.4252
#
# Number of clusters: 26
# Total fractal dimension: 3.3875
#
# Number of clusters: 27
# Total fractal dimension: 3.3416
#
# Number of clusters: 28
# Total fractal dimension: 3.3039
#
# Number of clusters: 29
# Total fractal dimension: 3.2697
#
# Number of clusters: 30
# Total fractal dimension: 3.2316
#
# Number of clusters: 31
# Total fractal dimension: 3.2015
#
# Number of clusters: 32
# Total fractal dimension: 3.1738
#
# Number of clusters: 33
# Total fractal dimension: 3.1486
#
# Number of clusters: 34
# Total fractal dimension: 3.1200
#
# Number of clusters: 35
# Total fractal dimension: 3.0995
#
# Number of clusters: 36
# Total fractal dimension: 3.0654
#
# Number of clusters: 37
# Total fractal dimension: 3.0396
#
# Number of clusters: 38
# Total fractal dimension: 3.0117
#
# Number of clusters: 39
# Total fractal dimension: 2.9970
#
# Number of clusters: 40
# Total fractal dimension: 2.9760
#
# Number of clusters: 41
# Total fractal dimension: 2.9537
#
# Number of clusters: 42
# Total fractal dimension: 2.9332
#
# Number of clusters: 43
# Total fractal dimension: 2.9148
#
# Number of clusters: 44
# Total fractal dimension: 2.8969
#
# Number of clusters: 45
# Total fractal dimension: 2.8780
#
# Number of clusters: 46
# Total fractal dimension: 2.8614
#
# Number of clusters: 47
# Total fractal dimension: 2.8451
#
# Number of clusters: 48
# Total fractal dimension: 2.8296
#
# Number of clusters: 49
# Total fractal dimension: 2.8134
#
# Number of clusters: 50
# Total fractal dimension: 2.7975
#
# Analyzing word: Go
#
# Number of clusters: 2
# Total fractal dimension: 16.3790
#
# Number of clusters: 3
# Total fractal dimension: 10.3336
#
# Number of clusters: 4
# Total fractal dimension: 8.1303
#
# Number of clusters: 5
# Total fractal dimension: 6.9852
#
# Number of clusters: 6
# Total fractal dimension: 6.2608
#
# Number of clusters: 7
# Total fractal dimension: 5.7654
#
# Number of clusters: 8
# Total fractal dimension: 5.3942
#
# Number of clusters: 9
# Total fractal dimension: 5.0949
#
# Number of clusters: 10
# Total fractal dimension: 4.8542
#
# Number of clusters: 11
# Total fractal dimension: 4.6510
#
# Number of clusters: 12
# Total fractal dimension: 4.4839
#
# Number of clusters: 13
# Total fractal dimension: 4.3345
#
# Number of clusters: 14
# Total fractal dimension: 4.2233
#
# Number of clusters: 15
# Total fractal dimension: 4.0995
#
# Number of clusters: 16
# Total fractal dimension: 4.0098
#
# Number of clusters: 17
# Total fractal dimension: 3.9208
#
# Number of clusters: 18
# Total fractal dimension: 3.8294
#
# Number of clusters: 19
# Total fractal dimension: 3.7558
#
# Number of clusters: 20
# Total fractal dimension: 3.6869
#
# Number of clusters: 21
# Total fractal dimension: 3.6375
#
# Number of clusters: 22
# Total fractal dimension: 3.5746
#
# Number of clusters: 23
# Total fractal dimension: 3.5167
#
# Number of clusters: 24
# Total fractal dimension: 3.4910
#
# Number of clusters: 25
# Total fractal dimension: 3.4351
#
# Number of clusters: 26
# Total fractal dimension: 3.3770
#
# Number of clusters: 27
# Total fractal dimension: 3.3448
#
# Number of clusters: 28
# Total fractal dimension: 3.2996
#
# Number of clusters: 29
# Total fractal dimension: 3.2673
#
# Number of clusters: 30
# Total fractal dimension: 3.2362
#
# Number of clusters: 31
# Total fractal dimension: 3.1954
#
# Number of clusters: 32
# Total fractal dimension: 3.1659
#
# Number of clusters: 33
# Total fractal dimension: 3.1381
#
# Number of clusters: 34
# Total fractal dimension: 3.1225
#
# Number of clusters: 35
# Total fractal dimension: 3.0905
#
# Number of clusters: 36
# Total fractal dimension: 3.0601
#
# Number of clusters: 37
# Total fractal dimension: 3.0533
#
# Number of clusters: 38
# Total fractal dimension: 3.0140
#
# Number of clusters: 39
# Total fractal dimension: 2.9888
#
# Number of clusters: 40
# Total fractal dimension: 2.9706
#
# Number of clusters: 41
# Total fractal dimension: 2.9490
#
# Number of clusters: 42
# Total fractal dimension: 2.9283
#
# Number of clusters: 43
# Total fractal dimension: 2.9097
#
# Number of clusters: 44
# Total fractal dimension: 2.8906
#
# Number of clusters: 45
# Total fractal dimension: 2.8726
#
# Number of clusters: 46
# Total fractal dimension: 2.8553
#
# Number of clusters: 47
# Total fractal dimension: 2.8391
#
# Number of clusters: 48
# Total fractal dimension: 2.8232
#
# Number of clusters: 49
# Total fractal dimension: 2.8081
#
# Number of clusters: 50
# Total fractal dimension: 2.7944
#
# Analyzing word: Take
#
# Number of clusters: 2
# Total fractal dimension: 16.3784
#
# Number of clusters: 3
# Total fractal dimension: 10.2901
#
# Number of clusters: 4
# Total fractal dimension: 8.1584
#
# Number of clusters: 5
# Total fractal dimension: 6.9837
#
# Number of clusters: 6
# Total fractal dimension: 6.2722
#
# Number of clusters: 7
# Total fractal dimension: 5.7648
#
# Number of clusters: 8
# Total fractal dimension: 5.3752
#
# Number of clusters: 9
# Total fractal dimension: 5.0792
#
# Number of clusters: 10
# Total fractal dimension: 4.8623
#
# Number of clusters: 11
# Total fractal dimension: 4.6543
#
# Number of clusters: 12
# Total fractal dimension: 4.4847
#
# Number of clusters: 13
# Total fractal dimension: 4.3308
#
# Number of clusters: 14
# Total fractal dimension: 4.2345
#
# Number of clusters: 15
# Total fractal dimension: 4.0937
#
# Number of clusters: 16
# Total fractal dimension: 4.0029
#
# Number of clusters: 17
# Total fractal dimension: 3.9244
#
# Number of clusters: 18
# Total fractal dimension: 3.8313
#
# Number of clusters: 19
# Total fractal dimension: 3.7521
#
# Number of clusters: 20
# Total fractal dimension: 3.6867
#
# Number of clusters: 21
# Total fractal dimension: 3.6316
#
# Number of clusters: 22
# Total fractal dimension: 3.5737
#
# Number of clusters: 23
# Total fractal dimension: 3.5208
#
# Number of clusters: 24
# Total fractal dimension: 3.5062
#
# Number of clusters: 25
# Total fractal dimension: 3.4259
#
# Number of clusters: 26
# Total fractal dimension: 3.3825
#
# Number of clusters: 27
# Total fractal dimension: 3.3358
#
# Number of clusters: 28
# Total fractal dimension: 3.3024
#
# Number of clusters: 29
# Total fractal dimension: 3.2658
#
# Number of clusters: 30
# Total fractal dimension: 3.2323
#
# Number of clusters: 31
# Total fractal dimension: 3.1982
#
# Number of clusters: 32
# Total fractal dimension: 3.1678
#
# Number of clusters: 33
# Total fractal dimension: 3.1408
#
# Number of clusters: 34
# Total fractal dimension: 3.1163
#
# Number of clusters: 35
# Total fractal dimension: 3.0987
#
# Number of clusters: 36
# Total fractal dimension: 3.0600
#
# Number of clusters: 37
# Total fractal dimension: 3.0401
#
# Number of clusters: 38
# Total fractal dimension: 3.0171
#
# Number of clusters: 39
# Total fractal dimension: 2.9864
#
# Number of clusters: 40
# Total fractal dimension: 2.9681
#
# Number of clusters: 41
# Total fractal dimension: 2.9483
#
# Number of clusters: 42
# Total fractal dimension: 2.9288
#
# Number of clusters: 43
# Total fractal dimension: 2.9094
#
# Number of clusters: 44
# Total fractal dimension: 2.8905
#
# Number of clusters: 45
# Total fractal dimension: 2.8721
#
# Number of clusters: 46
# Total fractal dimension: 2.8556
#
# Number of clusters: 47
# Total fractal dimension: 2.8397
#
# Number of clusters: 48
# Total fractal dimension: 2.8235
#
# Number of clusters: 49
# Total fractal dimension: 2.8078
#
# Number of clusters: 50
# Total fractal dimension: 2.7928
#
# Analyzing word: Get
#
# Number of clusters: 2
# Total fractal dimension: 16.3785
#
# Number of clusters: 3
# Total fractal dimension: 10.2939
#
# Number of clusters: 4
# Total fractal dimension: 8.1577
#
# Number of clusters: 5
# Total fractal dimension: 6.9877
#
# Number of clusters: 6
# Total fractal dimension: 6.2610
#
# Number of clusters: 7
# Total fractal dimension: 5.7650
#
# Number of clusters: 8
# Total fractal dimension: 5.3765
#
# Number of clusters: 9
# Total fractal dimension: 5.0880
#
# Number of clusters: 10
# Total fractal dimension: 4.8710
#
# Number of clusters: 11
# Total fractal dimension: 4.6521
#
# Number of clusters: 12
# Total fractal dimension: 4.4806
#
# Number of clusters: 13
# Total fractal dimension: 4.3350
#
# Number of clusters: 14
# Total fractal dimension: 4.2350
#
# Number of clusters: 15
# Total fractal dimension: 4.1018
#
# Number of clusters: 16
# Total fractal dimension: 4.0106
#
# Number of clusters: 17
# Total fractal dimension: 3.9100
#
# Number of clusters: 18
# Total fractal dimension: 3.8285
#
# Number of clusters: 19
# Total fractal dimension: 3.7534
#
# Number of clusters: 20
# Total fractal dimension: 3.6888
#
# Number of clusters: 21
# Total fractal dimension: 3.6401
#
# Number of clusters: 22
# Total fractal dimension: 3.5962
#
# Number of clusters: 23
# Total fractal dimension: 3.5164
#
# Number of clusters: 24
# Total fractal dimension: 3.4784
#
# Number of clusters: 25
# Total fractal dimension: 3.4304
#
# Number of clusters: 26
# Total fractal dimension: 3.3888
#
# Number of clusters: 27
# Total fractal dimension: 3.3435
#
# Number of clusters: 28
# Total fractal dimension: 3.3003
#
# Number of clusters: 29
# Total fractal dimension: 3.2661
#
# Number of clusters: 30
# Total fractal dimension: 3.2325
#
# Number of clusters: 31
# Total fractal dimension: 3.2031
#
# Number of clusters: 32
# Total fractal dimension: 3.1691
#
# Number of clusters: 33
# Total fractal dimension: 3.1431
#
# Number of clusters: 34
# Total fractal dimension: 3.1198
#
# Number of clusters: 35
# Total fractal dimension: 3.0919
#
# Number of clusters: 36
# Total fractal dimension: 3.0604
#
# Number of clusters: 37
# Total fractal dimension: 3.0395
#
# Number of clusters: 38
# Total fractal dimension: 3.0111
#
# Number of clusters: 39
# Total fractal dimension: 2.9902
#
# Number of clusters: 40
# Total fractal dimension: 2.9724
#
# Number of clusters: 41
# Total fractal dimension: 2.9508
#
# Number of clusters: 42
# Total fractal dimension: 2.9317
#
# Number of clusters: 43
# Total fractal dimension: 2.9126
#
# Number of clusters: 44
# Total fractal dimension: 2.8949
#
# Number of clusters: 45
# Total fractal dimension: 2.8767
#
# Number of clusters: 46
# Total fractal dimension: 2.8602
#
# Number of clusters: 47
# Total fractal dimension: 2.8435
#
# Number of clusters: 48
# Total fractal dimension: 2.8280
#
# Number of clusters: 49
# Total fractal dimension: 2.8130
#
# Number of clusters: 50
# Total fractal dimension: 2.7970
#
# Analyzing word: Make
#
# Number of clusters: 2
# Total fractal dimension: 16.3788
#
# Number of clusters: 3
# Total fractal dimension: 10.2904
#
# Number of clusters: 4
# Total fractal dimension: 8.1298
#
# Number of clusters: 5
# Total fractal dimension: 6.9896
#
# Number of clusters: 6
# Total fractal dimension: 6.2742
#
# Number of clusters: 7
# Total fractal dimension: 5.7564
#
# Number of clusters: 8
# Total fractal dimension: 5.3856
#
# Number of clusters: 9
# Total fractal dimension: 5.0798
#
# Number of clusters: 10
# Total fractal dimension: 4.8710
#
# Number of clusters: 11
# Total fractal dimension: 4.6435
#
# Number of clusters: 12
# Total fractal dimension: 4.4818
#
# Number of clusters: 13
# Total fractal dimension: 4.3503
#
# Number of clusters: 14
# Total fractal dimension: 4.2493
#
# Number of clusters: 15
# Total fractal dimension: 4.0932
#
# Number of clusters: 16
# Total fractal dimension: 4.0149
#
# Number of clusters: 17
# Total fractal dimension: 3.9203
#
# Number of clusters: 18
# Total fractal dimension: 3.8380
#
# Number of clusters: 19
# Total fractal dimension: 3.7544
#
# Number of clusters: 20
# Total fractal dimension: 3.6918
#
# Number of clusters: 21
# Total fractal dimension: 3.6303
#
# Number of clusters: 22
# Total fractal dimension: 3.5688
#
# Number of clusters: 23
# Total fractal dimension: 3.5210
#
# Number of clusters: 24
# Total fractal dimension: 3.4709
#
# Number of clusters: 25
# Total fractal dimension: 3.4306
#
# Number of clusters: 26
# Total fractal dimension: 3.3865
#
# Number of clusters: 27
# Total fractal dimension: 3.3401
#
# Number of clusters: 28
# Total fractal dimension: 3.2995
#
# Number of clusters: 29
# Total fractal dimension: 3.2620
#
# Number of clusters: 30
# Total fractal dimension: 3.2378
#
# Number of clusters: 31
# Total fractal dimension: 3.2023
#
# Number of clusters: 32
# Total fractal dimension: 3.1663
#
# Number of clusters: 33
# Total fractal dimension: 3.1453
#
# Number of clusters: 34
# Total fractal dimension: 3.1153
#
# Number of clusters: 35
# Total fractal dimension: 3.0875
#
# Number of clusters: 36
# Total fractal dimension: 3.0557
#
# Number of clusters: 37
# Total fractal dimension: 3.0473
#
# Number of clusters: 38
# Total fractal dimension: 3.0104
#
# Number of clusters: 39
# Total fractal dimension: 2.9933
#
# Number of clusters: 40
# Total fractal dimension: 2.9699
#
# Number of clusters: 41
# Total fractal dimension: 2.9487
#
# Number of clusters: 42
# Total fractal dimension: 2.9284
#
# Number of clusters: 43
# Total fractal dimension: 2.9101
#
# Number of clusters: 44
# Total fractal dimension: 2.8918
#
# Number of clusters: 45
# Total fractal dimension: 2.8747
#
# Number of clusters: 46
# Total fractal dimension: 2.8581
#
# Number of clusters: 47
# Total fractal dimension: 2.8408
#
# Number of clusters: 48
# Total fractal dimension: 2.8237
#
# Number of clusters: 49
# Total fractal dimension: 2.8081
#
# Number of clusters: 50
# Total fractal dimension: 2.7924
#
# Analyzing word: Put
#
# Number of clusters: 2
# Total fractal dimension: 16.3781
#
# Number of clusters: 3
# Total fractal dimension: 10.2912
#
# Number of clusters: 4
# Total fractal dimension: 8.1294
#
# Number of clusters: 5
# Total fractal dimension: 6.9849
#
# Number of clusters: 6
# Total fractal dimension: 6.2593
#
# Number of clusters: 7
# Total fractal dimension: 5.7537
#
# Number of clusters: 8
# Total fractal dimension: 5.3939
#
# Number of clusters: 9
# Total fractal dimension: 5.0871
#
# Number of clusters: 10
# Total fractal dimension: 4.8440
#
# Number of clusters: 11
# Total fractal dimension: 4.6497
#
# Number of clusters: 12
# Total fractal dimension: 4.4805
#
# Number of clusters: 13
# Total fractal dimension: 4.3308
#
# Number of clusters: 14
# Total fractal dimension: 4.2498
#
# Number of clusters: 15
# Total fractal dimension: 4.0949
#
# Number of clusters: 16
# Total fractal dimension: 4.0023
#
# Number of clusters: 17
# Total fractal dimension: 3.9505
#
# Number of clusters: 18
# Total fractal dimension: 3.8334
#
# Number of clusters: 19
# Total fractal dimension: 3.7575
#
# Number of clusters: 20
# Total fractal dimension: 3.6859
#
# Number of clusters: 21
# Total fractal dimension: 3.6365
#
# Number of clusters: 22
# Total fractal dimension: 3.5743
#
# Number of clusters: 23
# Total fractal dimension: 3.5210
#
# Number of clusters: 24
# Total fractal dimension: 3.4975
#
# Number of clusters: 25
# Total fractal dimension: 3.4349
#
# Number of clusters: 26
# Total fractal dimension: 3.3826
#
# Number of clusters: 27
# Total fractal dimension: 3.3439
#
# Number of clusters: 28
# Total fractal dimension: 3.2988
#
# Number of clusters: 29
# Total fractal dimension: 3.2622
#
# Number of clusters: 30
# Total fractal dimension: 3.2365
#
# Number of clusters: 31
# Total fractal dimension: 3.1976
#
# Number of clusters: 32
# Total fractal dimension: 3.1715
#
# Number of clusters: 33
# Total fractal dimension: 3.1398
#
# Number of clusters: 34
# Total fractal dimension: 3.1220
#
# Number of clusters: 35
# Total fractal dimension: 3.0971
#
# Number of clusters: 36
# Total fractal dimension: 3.0570
#
# Number of clusters: 37
# Total fractal dimension: 3.0479
#
# Number of clusters: 38
# Total fractal dimension: 3.0119
#
# Number of clusters: 39
# Total fractal dimension: 2.9848
#
# Number of clusters: 40
# Total fractal dimension: 2.9726
#
# Number of clusters: 41
# Total fractal dimension: 2.9529
#
# Number of clusters: 42
# Total fractal dimension: 2.9339
#
# Number of clusters: 43
# Total fractal dimension: 2.9154
#
# Number of clusters: 44
# Total fractal dimension: 2.8964
#
# Number of clusters: 45
# Total fractal dimension: 2.8781
#
# Number of clusters: 46
# Total fractal dimension: 2.8614
#
# Number of clusters: 47
# Total fractal dimension: 2.8441
#
# Number of clusters: 48
# Total fractal dimension: 2.8273
#
# Number of clusters: 49
# Total fractal dimension: 2.8112
#
# Number of clusters: 50
# Total fractal dimension: 2.7956
#
# Analyzing word: Stand
#
# Number of clusters: 2
# Total fractal dimension: 16.3783
#
# Number of clusters: 3
# Total fractal dimension: 10.2900
#
# Number of clusters: 4
# Total fractal dimension: 8.1287
#
# Number of clusters: 5
# Total fractal dimension: 6.9836
#
# Number of clusters: 6
# Total fractal dimension: 6.2611
#
# Number of clusters: 7
# Total fractal dimension: 5.7645
#
# Number of clusters: 8
# Total fractal dimension: 5.3852
#
# Number of clusters: 9
# Total fractal dimension: 5.1048
#
# Number of clusters: 10
# Total fractal dimension: 4.8535
#
# Number of clusters: 11
# Total fractal dimension: 4.6609
#
# Number of clusters: 12
# Total fractal dimension: 4.4744
#
# Number of clusters: 13
# Total fractal dimension: 4.3322
#
# Number of clusters: 14
# Total fractal dimension: 4.2500
#
# Number of clusters: 15
# Total fractal dimension: 4.1023
#
# Number of clusters: 16
# Total fractal dimension: 4.0021
#
# Number of clusters: 17
# Total fractal dimension: 3.9285
#
# Number of clusters: 18
# Total fractal dimension: 3.8381
#
# Number of clusters: 19
# Total fractal dimension: 3.7578
#
# Number of clusters: 20
# Total fractal dimension: 3.6864
#
# Number of clusters: 21
# Total fractal dimension: 3.6344
#
# Number of clusters: 22
# Total fractal dimension: 3.6006
#
# Number of clusters: 23
# Total fractal dimension: 3.5231
#
# Number of clusters: 24
# Total fractal dimension: 3.4692
#
# Number of clusters: 25
# Total fractal dimension: 3.4233
#
# Number of clusters: 26
# Total fractal dimension: 3.3848
#
# Number of clusters: 27
# Total fractal dimension: 3.3409
#
# Number of clusters: 28
# Total fractal dimension: 3.3080
#
# Number of clusters: 29
# Total fractal dimension: 3.2679
#
# Number of clusters: 30
# Total fractal dimension: 3.2368
#
# Number of clusters: 31
# Total fractal dimension: 3.2002
#
# Number of clusters: 32
# Total fractal dimension: 3.1664
#
# Number of clusters: 33
# Total fractal dimension: 3.1498
#
# Number of clusters: 34
# Total fractal dimension: 3.1227
#
# Number of clusters: 35
# Total fractal dimension: 3.0917
#
# Number of clusters: 36
# Total fractal dimension: 3.0589
#
# Number of clusters: 37
# Total fractal dimension: 3.0429
#
# Number of clusters: 38
# Total fractal dimension: 3.0200
#
# Number of clusters: 39
# Total fractal dimension: 2.9929
#
# Number of clusters: 40
# Total fractal dimension: 2.9734
#
# Number of clusters: 41
# Total fractal dimension: 2.9522
#
# Number of clusters: 42
# Total fractal dimension: 2.9331
#
# Number of clusters: 43
# Total fractal dimension: 2.9147
#
# Number of clusters: 44
# Total fractal dimension: 2.8956
#
# Number of clusters: 45
# Total fractal dimension: 2.8770
#
# Number of clusters: 46
# Total fractal dimension: 2.8605
#
# Number of clusters: 47
# Total fractal dimension: 2.8433
#
# Number of clusters: 48
# Total fractal dimension: 2.8279
#
# Number of clusters: 49
# Total fractal dimension: 2.8110
#
# Number of clusters: 50
# Total fractal dimension: 2.7958
#
# Analyzing word: Hold
#
# Number of clusters: 2
# Total fractal dimension: 16.3781
#
# Number of clusters: 3
# Total fractal dimension: 10.2899
#
# Number of clusters: 4
# Total fractal dimension: 8.1295
#
# Number of clusters: 5
# Total fractal dimension: 6.9836
#
# Number of clusters: 6
# Total fractal dimension: 6.2595
#
# Number of clusters: 7
# Total fractal dimension: 5.7637
#
# Number of clusters: 8
# Total fractal dimension: 5.3929
#
# Number of clusters: 9
# Total fractal dimension: 5.0791
#
# Number of clusters: 10
# Total fractal dimension: 4.8811
#
# Number of clusters: 11
# Total fractal dimension: 4.6618
#
# Number of clusters: 12
# Total fractal dimension: 4.4750
#
# Number of clusters: 13
# Total fractal dimension: 4.3357
#
# Number of clusters: 14
# Total fractal dimension: 4.2428
#
# Number of clusters: 15
# Total fractal dimension: 4.0946
#
# Number of clusters: 16
# Total fractal dimension: 4.0057
#
# Number of clusters: 17
# Total fractal dimension: 3.9573
#
# Number of clusters: 18
# Total fractal dimension: 3.8255
#
# Number of clusters: 19
# Total fractal dimension: 3.7555
#
# Number of clusters: 20
# Total fractal dimension: 3.6886
#
# Number of clusters: 21
# Total fractal dimension: 3.6288
#
# Number of clusters: 22
# Total fractal dimension: 3.5696
#
# Number of clusters: 23
# Total fractal dimension: 3.5258
#
# Number of clusters: 24
# Total fractal dimension: 3.4786
#
# Number of clusters: 25
# Total fractal dimension: 3.4229
#
# Number of clusters: 26
# Total fractal dimension: 3.3888
#
# Number of clusters: 27
# Total fractal dimension: 3.3407
#
# Number of clusters: 28
# Total fractal dimension: 3.3045
#
# Number of clusters: 29
# Total fractal dimension: 3.2647
#
# Number of clusters: 30
# Total fractal dimension: 3.2381
#
# Number of clusters: 31
# Total fractal dimension: 3.1993
#
# Number of clusters: 32
# Total fractal dimension: 3.1668
#
# Number of clusters: 33
# Total fractal dimension: 3.1443
#
# Number of clusters: 34
# Total fractal dimension: 3.1142
#
# Number of clusters: 35
# Total fractal dimension: 3.0887
#
# Number of clusters: 36
# Total fractal dimension: 3.0581
#
# Number of clusters: 37
# Total fractal dimension: 3.0545
#
# Number of clusters: 38
# Total fractal dimension: 3.0102
#
# Number of clusters: 39
# Total fractal dimension: 2.9938
#
# Number of clusters: 40
# Total fractal dimension: 2.9724
#
# Number of clusters: 41
# Total fractal dimension: 2.9512
#
# Number of clusters: 42
# Total fractal dimension: 2.9308
#
# Number of clusters: 43
# Total fractal dimension: 2.9115
#
# Number of clusters: 44
# Total fractal dimension: 2.8938
#
# Number of clusters: 45
# Total fractal dimension: 2.8764
#
# Number of clusters: 46
# Total fractal dimension: 2.8585
#
# Number of clusters: 47
# Total fractal dimension: 2.8424
#
# Number of clusters: 48
# Total fractal dimension: 2.8250
#
# Number of clusters: 49
# Total fractal dimension: 2.8090
#
# Number of clusters: 50
# Total fractal dimension: 2.7938
#
# Analyzing word: Turn
#
# Number of clusters: 2
# Total fractal dimension: 16.3782
#
# Number of clusters: 3
# Total fractal dimension: 10.2914
#
# Number of clusters: 4
# Total fractal dimension: 8.1542
#
# Number of clusters: 5
# Total fractal dimension: 6.9849
#
# Number of clusters: 6
# Total fractal dimension: 6.2606
#
# Number of clusters: 7
# Total fractal dimension: 5.7680
#
# Number of clusters: 8
# Total fractal dimension: 5.3753
#
# Number of clusters: 9
# Total fractal dimension: 5.0805
#
# Number of clusters: 10
# Total fractal dimension: 4.8712
#
# Number of clusters: 11
# Total fractal dimension: 4.6422
#
# Number of clusters: 12
# Total fractal dimension: 4.4984
#
# Number of clusters: 13
# Total fractal dimension: 4.3322
#
# Number of clusters: 14
# Total fractal dimension: 4.2496
#
# Number of clusters: 15
# Total fractal dimension: 4.0945
#
# Number of clusters: 16
# Total fractal dimension: 4.0197
#
# Number of clusters: 17
# Total fractal dimension: 3.9498
#
# Number of clusters: 18
# Total fractal dimension: 3.8288
#
# Number of clusters: 19
# Total fractal dimension: 3.7612
#
# Number of clusters: 20
# Total fractal dimension: 3.6973
#
# Number of clusters: 21
# Total fractal dimension: 3.6280
#
# Number of clusters: 22
# Total fractal dimension: 3.5730
#
# Number of clusters: 23
# Total fractal dimension: 3.5225
#
# Number of clusters: 24
# Total fractal dimension: 3.4986
#
# Number of clusters: 25
# Total fractal dimension: 3.4356
#
# Number of clusters: 26
# Total fractal dimension: 3.3811
#
# Number of clusters: 27
# Total fractal dimension: 3.3429
#
# Number of clusters: 28
# Total fractal dimension: 3.3066
#
# Number of clusters: 29
# Total fractal dimension: 3.2642
#
# Number of clusters: 30
# Total fractal dimension: 3.2326
#
# Number of clusters: 31
# Total fractal dimension: 3.2023
#
# Number of clusters: 32
# Total fractal dimension: 3.1679
#
# Number of clusters: 33
# Total fractal dimension: 3.1479
#
# Number of clusters: 34
# Total fractal dimension: 3.1156
#
# Number of clusters: 35
# Total fractal dimension: 3.0952
#
# Number of clusters: 36
# Total fractal dimension: 3.0615
#
# Number of clusters: 37
# Total fractal dimension: 3.0448
#
# Number of clusters: 38
# Total fractal dimension: 3.0150
#
# Number of clusters: 39
# Total fractal dimension: 2.9900
#
# Number of clusters: 40
# Total fractal dimension: 2.9715
#
# Number of clusters: 41
# Total fractal dimension: 2.9502
#
# Number of clusters: 42
# Total fractal dimension: 2.9302
#
# Number of clusters: 43
# Total fractal dimension: 2.9101
#
# Number of clusters: 44
# Total fractal dimension: 2.8916
#
# Number of clusters: 45
# Total fractal dimension: 2.8730
#
# Number of clusters: 46
# Total fractal dimension: 2.8555
#
# Number of clusters: 47
# Total fractal dimension: 2.8390
#
# Number of clusters: 48
# Total fractal dimension: 2.8224
#
# Number of clusters: 49
# Total fractal dimension: 2.8062
#
# Number of clusters: 50
# Total fractal dimension: 2.7904
#
# Analyzing word: Break
#
# Number of clusters: 2
# Total fractal dimension: 16.3783
#
# Number of clusters: 3
# Total fractal dimension: 10.2897
#
# Number of clusters: 4
# Total fractal dimension: 8.1312
#
# Number of clusters: 5
# Total fractal dimension: 6.9844
#
# Number of clusters: 6
# Total fractal dimension: 6.2597
#
# Number of clusters: 7
# Total fractal dimension: 5.7646
#
# Number of clusters: 8
# Total fractal dimension: 5.3766
#
# Number of clusters: 9
# Total fractal dimension: 5.0810
#
# Number of clusters: 10
# Total fractal dimension: 4.8459
#
# Number of clusters: 11
# Total fractal dimension: 4.6687
#
# Number of clusters: 12
# Total fractal dimension: 4.4794
#
# Number of clusters: 13
# Total fractal dimension: 4.3301
#
# Number of clusters: 14
# Total fractal dimension: 4.2281
#
# Number of clusters: 15
# Total fractal dimension: 4.1023
#
# Number of clusters: 16
# Total fractal dimension: 3.9947
#
# Number of clusters: 17
# Total fractal dimension: 3.9455
#
# Number of clusters: 18
# Total fractal dimension: 3.8311
#
# Number of clusters: 19
# Total fractal dimension: 3.7568
#
# Number of clusters: 20
# Total fractal dimension: 3.6881
#
# Number of clusters: 21
# Total fractal dimension: 3.6339
#
# Number of clusters: 22
# Total fractal dimension: 3.5775
#
# Number of clusters: 23
# Total fractal dimension: 3.5217
#
# Number of clusters: 24
# Total fractal dimension: 3.4685
#
# Number of clusters: 25
# Total fractal dimension: 3.4276
#
# Number of clusters: 26
# Total fractal dimension: 3.3954
#
# Number of clusters: 27
# Total fractal dimension: 3.3401
#
# Number of clusters: 28
# Total fractal dimension: 3.3091
#
# Number of clusters: 29
# Total fractal dimension: 3.2663
#
# Number of clusters: 30
# Total fractal dimension: 3.2359
#
# Number of clusters: 31
# Total fractal dimension: 3.1993
#
# Number of clusters: 32
# Total fractal dimension: 3.1646
#
# Number of clusters: 33
# Total fractal dimension: 3.1434
#
# Number of clusters: 34
# Total fractal dimension: 3.1196
#
# Number of clusters: 35
# Total fractal dimension: 3.0948
#
# Number of clusters: 36
# Total fractal dimension: 3.0604
#
# Number of clusters: 37
# Total fractal dimension: 3.0412
#
# Number of clusters: 38
# Total fractal dimension: 3.0196
#
# Number of clusters: 39
# Total fractal dimension: 2.9937
#
# Number of clusters: 40
# Total fractal dimension: 2.9687
#
# Number of clusters: 41
# Total fractal dimension: 2.9488
#
# Number of clusters: 42
# Total fractal dimension: 2.9282
#
# Number of clusters: 43
# Total fractal dimension: 2.9086
#
# Number of clusters: 44
# Total fractal dimension: 2.8907
#
# Number of clusters: 45
# Total fractal dimension: 2.8726
#
# Number of clusters: 46
# Total fractal dimension: 2.8561
#
# Number of clusters: 47
# Total fractal dimension: 2.8402
#
# Number of clusters: 48
# Total fractal dimension: 2.8246
#
# Number of clusters: 49
# Total fractal dimension: 2.8083
#
# Number of clusters: 50
# Total fractal dimension: 2.7928
#
# Analyzing word: Fall
#
# Number of clusters: 2
# Total fractal dimension: 16.3790
#
# Number of clusters: 3
# Total fractal dimension: 10.2921
#
# Number of clusters: 4
# Total fractal dimension: 8.1295
#
# Number of clusters: 5
# Total fractal dimension: 6.9841
#
# Number of clusters: 6
# Total fractal dimension: 6.2629
#
# Number of clusters: 7
# Total fractal dimension: 5.7645
#
# Number of clusters: 8
# Total fractal dimension: 5.3745
#
# Number of clusters: 9
# Total fractal dimension: 5.0872
#
# Number of clusters: 10
# Total fractal dimension: 4.8469
#
# Number of clusters: 11
# Total fractal dimension: 4.6539
#
# Number of clusters: 12
# Total fractal dimension: 4.4981
#
# Number of clusters: 13
# Total fractal dimension: 4.3309
#
# Number of clusters: 14
# Total fractal dimension: 4.2201
#
# Number of clusters: 15
# Total fractal dimension: 4.0970
#
# Number of clusters: 16
# Total fractal dimension: 4.0063
#
# Number of clusters: 17
# Total fractal dimension: 3.9286
#
# Number of clusters: 18
# Total fractal dimension: 3.8378
#
# Number of clusters: 19
# Total fractal dimension: 3.7611
#
# Number of clusters: 20
# Total fractal dimension: 3.6938
#
# Number of clusters: 21
# Total fractal dimension: 3.6270
#
# Number of clusters: 22
# Total fractal dimension: 3.5780
#
# Number of clusters: 23
# Total fractal dimension: 3.5236
#
# Number of clusters: 24
# Total fractal dimension: 3.4906
#
# Number of clusters: 25
# Total fractal dimension: 3.4218
#
# Number of clusters: 26
# Total fractal dimension: 3.4015
#
# Number of clusters: 27
# Total fractal dimension: 3.3441
#
# Number of clusters: 28
# Total fractal dimension: 3.3067
#
# Number of clusters: 29
# Total fractal dimension: 3.2697
#
# Number of clusters: 30
# Total fractal dimension: 3.2327
#
# Number of clusters: 31
# Total fractal dimension: 3.2102
#
# Number of clusters: 32
# Total fractal dimension: 3.1676
#
# Number of clusters: 33
# Total fractal dimension: 3.1403
#
# Number of clusters: 34
# Total fractal dimension: 3.1163
#
# Number of clusters: 35
# Total fractal dimension: 3.0867
#
# Number of clusters: 36
# Total fractal dimension: 3.0592
#
# Number of clusters: 37
# Total fractal dimension: 3.0520
#
# Number of clusters: 38
# Total fractal dimension: 3.0140
#
# Number of clusters: 39
# Total fractal dimension: 2.9952
#
# Number of clusters: 40
# Total fractal dimension: 2.9819
#
# Number of clusters: 41
# Total fractal dimension: 2.9605
#
# Number of clusters: 42
# Total fractal dimension: 2.9412
#
# Number of clusters: 43
# Total fractal dimension: 2.9212
#
# Number of clusters: 44
# Total fractal dimension: 2.9033
#
# Number of clusters: 45
# Total fractal dimension: 2.8851
#
# Number of clusters: 46
# Total fractal dimension: 2.8685
#
# Number of clusters: 47
# Total fractal dimension: 2.8510
#
# Number of clusters: 48
# Total fractal dimension: 2.8342
#
# Number of clusters: 49
# Total fractal dimension: 2.8193
#
# Number of clusters: 50
# Total fractal dimension: 2.8046
#
# Analyzing word: Cut
#
# Number of clusters: 2
# Total fractal dimension: 16.3874
#
# Number of clusters: 3
# Total fractal dimension: 10.2923
#
# Number of clusters: 4
# Total fractal dimension: 8.1319
#
# Number of clusters: 5
# Total fractal dimension: 6.9833
#
# Number of clusters: 6
# Total fractal dimension: 6.2594
#
# Number of clusters: 7
# Total fractal dimension: 5.7534
#
# Number of clusters: 8
# Total fractal dimension: 5.3832
#
# Number of clusters: 9
# Total fractal dimension: 5.0824
#
# Number of clusters: 10
# Total fractal dimension: 4.8931
#
# Number of clusters: 11
# Total fractal dimension: 4.6531
#
# Number of clusters: 12
# Total fractal dimension: 4.4823
#
# Number of clusters: 13
# Total fractal dimension: 4.3411
#
# Number of clusters: 14
# Total fractal dimension: 4.2376
#
# Number of clusters: 15
# Total fractal dimension: 4.0971
#
# Number of clusters: 16
# Total fractal dimension: 4.0073
#
# Number of clusters: 17
# Total fractal dimension: 3.9364
#
# Number of clusters: 18
# Total fractal dimension: 3.8303
#
# Number of clusters: 19
# Total fractal dimension: 3.7574
#
# Number of clusters: 20
# Total fractal dimension: 3.6912
#
# Number of clusters: 21
# Total fractal dimension: 3.6357
#
# Number of clusters: 22
# Total fractal dimension: 3.5744
#
# Number of clusters: 23
# Total fractal dimension: 3.5204
#
# Number of clusters: 24
# Total fractal dimension: 3.4669
#
# Number of clusters: 25
# Total fractal dimension: 3.4428
#
# Number of clusters: 26
# Total fractal dimension: 3.3847
#
# Number of clusters: 27
# Total fractal dimension: 3.3442
#
# Number of clusters: 28
# Total fractal dimension: 3.2991
#
# Number of clusters: 29
# Total fractal dimension: 3.2683
#
# Number of clusters: 30
# Total fractal dimension: 3.2363
#
# Number of clusters: 31
# Total fractal dimension: 3.1969
#
# Number of clusters: 32
# Total fractal dimension: 3.1672
#
# Number of clusters: 33
# Total fractal dimension: 3.1412
#
# Number of clusters: 34
# Total fractal dimension: 3.1213
#
# Number of clusters: 35
# Total fractal dimension: 3.0983
#
# Number of clusters: 36
# Total fractal dimension: 3.0604
#
# Number of clusters: 37
# Total fractal dimension: 3.0446
#
# Number of clusters: 38
# Total fractal dimension: 3.0124
#
# Number of clusters: 39
# Total fractal dimension: 2.9891
#
# Number of clusters: 40
# Total fractal dimension: 2.9648
#
# Number of clusters: 41
# Total fractal dimension: 2.9454
#
# Number of clusters: 42
# Total fractal dimension: 2.9261
#
# Number of clusters: 43
# Total fractal dimension: 2.9069
#
# Number of clusters: 44
# Total fractal dimension: 2.8897
#
# Number of clusters: 45
# Total fractal dimension: 2.8711
#
# Number of clusters: 46
# Total fractal dimension: 2.8545
#
# Number of clusters: 47
# Total fractal dimension: 2.8370
#
# Number of clusters: 48
# Total fractal dimension: 2.8213
#
# Number of clusters: 49
# Total fractal dimension: 2.8053
#
# Number of clusters: 50
# Total fractal dimension: 2.7897
#
# Analyzing word: Pass
#
# Number of clusters: 2
# Total fractal dimension: 16.3789
#
# Number of clusters: 3
# Total fractal dimension: 10.2901
#
# Number of clusters: 4
# Total fractal dimension: 8.1286
#
# Number of clusters: 5
# Total fractal dimension: 6.9867
#
# Number of clusters: 6
# Total fractal dimension: 6.2599
#
# Number of clusters: 7
# Total fractal dimension: 5.7554
#
# Number of clusters: 8
# Total fractal dimension: 5.3765
#
# Number of clusters: 9
# Total fractal dimension: 5.0794
#
# Number of clusters: 10
# Total fractal dimension: 4.8403
#
# Number of clusters: 11
# Total fractal dimension: 4.6694
#
# Number of clusters: 12
# Total fractal dimension: 4.4752
#
# Number of clusters: 13
# Total fractal dimension: 4.3299
#
# Number of clusters: 14
# Total fractal dimension: 4.2125
#
# Number of clusters: 15
# Total fractal dimension: 4.0995
#
# Number of clusters: 16
# Total fractal dimension: 4.0070
#
# Number of clusters: 17
# Total fractal dimension: 3.9072
#
# Number of clusters: 18
# Total fractal dimension: 3.8291
#
# Number of clusters: 19
# Total fractal dimension: 3.7617
#
# Number of clusters: 20
# Total fractal dimension: 3.6967
#
# Number of clusters: 21
# Total fractal dimension: 3.6270
#
# Number of clusters: 22
# Total fractal dimension: 3.5777
#
# Number of clusters: 23
# Total fractal dimension: 3.5241
#
# Number of clusters: 24
# Total fractal dimension: 3.4758
#
# Number of clusters: 25
# Total fractal dimension: 3.4263
#
# Number of clusters: 26
# Total fractal dimension: 3.3830
#
# Number of clusters: 27
# Total fractal dimension: 3.3544
#
# Number of clusters: 28
# Total fractal dimension: 3.3074
#
# Number of clusters: 29
# Total fractal dimension: 3.2708
#
# Number of clusters: 30
# Total fractal dimension: 3.2363
#
# Number of clusters: 31
# Total fractal dimension: 3.2008
#
# Number of clusters: 32
# Total fractal dimension: 3.1758
#
# Number of clusters: 33
# Total fractal dimension: 3.1428
#
# Number of clusters: 34
# Total fractal dimension: 3.1134
#
# Number of clusters: 35
# Total fractal dimension: 3.0871
#
# Number of clusters: 36
# Total fractal dimension: 3.0682
#
# Number of clusters: 37
# Total fractal dimension: 3.0455
#
# Number of clusters: 38
# Total fractal dimension: 3.0208
#
# Number of clusters: 39
# Total fractal dimension: 2.9891
#
# Number of clusters: 40
# Total fractal dimension: 2.9723
#
# Number of clusters: 41
# Total fractal dimension: 2.9523
#
# Number of clusters: 42
# Total fractal dimension: 2.9331
#
# Number of clusters: 43
# Total fractal dimension: 2.9131
#
# Number of clusters: 44
# Total fractal dimension: 2.8941
#
# Number of clusters: 45
# Total fractal dimension: 2.8770
#
# Number of clusters: 46
# Total fractal dimension: 2.8604
#
# Number of clusters: 47
# Total fractal dimension: 2.8434
#
# Number of clusters: 48
# Total fractal dimension: 2.8268
#
# Number of clusters: 49
# Total fractal dimension: 2.8106
#
# Number of clusters: 50
# Total fractal dimension: 2.7949
#
# Analyzing word: Bring
#
# Number of clusters: 2
# Total fractal dimension: 16.3783
#
# Number of clusters: 3
# Total fractal dimension: 10.2900
#
# Number of clusters: 4
# Total fractal dimension: 8.1290
#
# Number of clusters: 5
# Total fractal dimension: 6.9836
#
# Number of clusters: 6
# Total fractal dimension: 6.2722
#
# Number of clusters: 7
# Total fractal dimension: 5.7638
#
# Number of clusters: 8
# Total fractal dimension: 5.3856
#
# Number of clusters: 9
# Total fractal dimension: 5.0878
#
# Number of clusters: 10
# Total fractal dimension: 4.8931
#
# Number of clusters: 11
# Total fractal dimension: 4.6680
#
# Number of clusters: 12
# Total fractal dimension: 4.4749
#
# Number of clusters: 13
# Total fractal dimension: 4.3388
#
# Number of clusters: 14
# Total fractal dimension: 4.2132
#
# Number of clusters: 15
# Total fractal dimension: 4.0935
#
# Number of clusters: 16
# Total fractal dimension: 3.9977
#
# Number of clusters: 17
# Total fractal dimension: 3.9126
#
# Number of clusters: 18
# Total fractal dimension: 3.8316
#
# Number of clusters: 19
# Total fractal dimension: 3.7604
#
# Number of clusters: 20
# Total fractal dimension: 3.6905
#
# Number of clusters: 21
# Total fractal dimension: 3.6370
#
# Number of clusters: 22
# Total fractal dimension: 3.5713
#
# Number of clusters: 23
# Total fractal dimension: 3.5202
#
# Number of clusters: 24
# Total fractal dimension: 3.4845
#
# Number of clusters: 25
# Total fractal dimension: 3.4272
#
# Number of clusters: 26
# Total fractal dimension: 3.3821
#
# Number of clusters: 27
# Total fractal dimension: 3.3493
#
# Number of clusters: 28
# Total fractal dimension: 3.2975
#
# Number of clusters: 29
# Total fractal dimension: 3.2712
#
# Number of clusters: 30
# Total fractal dimension: 3.2318
#
# Number of clusters: 31
# Total fractal dimension: 3.2037
#
# Number of clusters: 32
# Total fractal dimension: 3.1663
#
# Number of clusters: 33
# Total fractal dimension: 3.1412
#
# Number of clusters: 34
# Total fractal dimension: 3.1198
#
# Number of clusters: 35
# Total fractal dimension: 3.0948
#
# Number of clusters: 36
# Total fractal dimension: 3.0550
#
# Number of clusters: 37
# Total fractal dimension: 3.0319
#
# Number of clusters: 38
# Total fractal dimension: 3.0158
#
# Number of clusters: 39
# Total fractal dimension: 2.9926
#
# Number of clusters: 40
# Total fractal dimension: 2.9665
#
# Number of clusters: 41
# Total fractal dimension: 2.9455
#
# Number of clusters: 42
# Total fractal dimension: 2.9253
#
# Number of clusters: 43
# Total fractal dimension: 2.9069
#
# Number of clusters: 44
# Total fractal dimension: 2.8888
#
# Number of clusters: 45
# Total fractal dimension: 2.8700
#
# Number of clusters: 46
# Total fractal dimension: 2.8531
#
# Number of clusters: 47
# Total fractal dimension: 2.8353
#
# Number of clusters: 48
# Total fractal dimension: 2.8189
#
# Number of clusters: 49
# Total fractal dimension: 2.8040
#
# Number of clusters: 50
# Total fractal dimension: 2.7892
#
# Analyzing word: Do
#
# Number of clusters: 2
# Total fractal dimension: 16.3783
#
# Number of clusters: 3
# Total fractal dimension: 10.2903
#
# Number of clusters: 4
# Total fractal dimension: 8.1303
#
# Number of clusters: 5
# Total fractal dimension: 6.9873
#
# Number of clusters: 6
# Total fractal dimension: 6.2637
#
# Number of clusters: 7
# Total fractal dimension: 5.7646
#
# Number of clusters: 8
# Total fractal dimension: 5.3767
#
# Number of clusters: 9
# Total fractal dimension: 5.0823
#
# Number of clusters: 10
# Total fractal dimension: 4.8653
#
# Number of clusters: 11
# Total fractal dimension: 4.6487
#
# Number of clusters: 12
# Total fractal dimension: 4.4838
#
# Number of clusters: 13
# Total fractal dimension: 4.3361
#
# Number of clusters: 14
# Total fractal dimension: 4.2147
#
# Number of clusters: 15
# Total fractal dimension: 4.1032
#
# Number of clusters: 16
# Total fractal dimension: 4.0081
#
# Number of clusters: 17
# Total fractal dimension: 3.9339
#
# Number of clusters: 18
# Total fractal dimension: 3.8317
#
# Number of clusters: 19
# Total fractal dimension: 3.7537
#
# Number of clusters: 20
# Total fractal dimension: 3.6895
#
# Number of clusters: 21
# Total fractal dimension: 3.6270
#
# Number of clusters: 22
# Total fractal dimension: 3.5731
#
# Number of clusters: 23
# Total fractal dimension: 3.5221
#
# Number of clusters: 24
# Total fractal dimension: 3.4707
#
# Number of clusters: 25
# Total fractal dimension: 3.4295
#
# Number of clusters: 26
# Total fractal dimension: 3.3863
#
# Number of clusters: 27
# Total fractal dimension: 3.3372
#
# Number of clusters: 28
# Total fractal dimension: 3.3021
#
# Number of clusters: 29
# Total fractal dimension: 3.2655
#
# Number of clusters: 30
# Total fractal dimension: 3.2365
#
# Number of clusters: 31
# Total fractal dimension: 3.1956
#
# Number of clusters: 32
# Total fractal dimension: 3.1656
#
# Number of clusters: 33
# Total fractal dimension: 3.1397
#
# Number of clusters: 34
# Total fractal dimension: 3.1139
#
# Number of clusters: 35
# Total fractal dimension: 3.0915
#
# Number of clusters: 36
# Total fractal dimension: 3.0611
#
# Number of clusters: 37
# Total fractal dimension: 3.0447
#
# Number of clusters: 38
# Total fractal dimension: 3.0128
#
# Number of clusters: 39
# Total fractal dimension: 2.9854
#
# Number of clusters: 40
# Total fractal dimension: 2.9732
#
# Number of clusters: 41
# Total fractal dimension: 2.9522
#
# Number of clusters: 42
# Total fractal dimension: 2.9318
#
# Number of clusters: 43
# Total fractal dimension: 2.9121
#
# Number of clusters: 44
# Total fractal dimension: 2.8943
#
# Number of clusters: 45
# Total fractal dimension: 2.8760
#
# Number of clusters: 46
# Total fractal dimension: 2.8595
#
# Number of clusters: 47
# Total fractal dimension: 2.8423
#
# Number of clusters: 48
# Total fractal dimension: 2.8268
#
# Number of clusters: 49
# Total fractal dimension: 2.8107
#
# Number of clusters: 50
# Total fractal dimension: 2.7947
#
# Analyzing word: Catch
#
# Number of clusters: 2
# Total fractal dimension: 16.3784
#
# Number of clusters: 3
# Total fractal dimension: 10.2907
#
# Number of clusters: 4
# Total fractal dimension: 8.1285
#
# Number of clusters: 5
# Total fractal dimension: 6.9851
#
# Number of clusters: 6
# Total fractal dimension: 6.2620
#
# Number of clusters: 7
# Total fractal dimension: 5.7544
#
# Number of clusters: 8
# Total fractal dimension: 5.3764
#
# Number of clusters: 9
# Total fractal dimension: 5.0804
#
# Number of clusters: 10
# Total fractal dimension: 4.8545
#
# Number of clusters: 11
# Total fractal dimension: 4.6493
#
# Number of clusters: 12
# Total fractal dimension: 4.4776
#
# Number of clusters: 13
# Total fractal dimension: 4.3350
#
# Number of clusters: 14
# Total fractal dimension: 4.2302
#
# Number of clusters: 15
# Total fractal dimension: 4.0939
#
# Number of clusters: 16
# Total fractal dimension: 4.0141
#
# Number of clusters: 17
# Total fractal dimension: 3.9284
#
# Number of clusters: 18
# Total fractal dimension: 3.8328
#
# Number of clusters: 19
# Total fractal dimension: 3.7585
#
# Number of clusters: 20
# Total fractal dimension: 3.6942
#
# Number of clusters: 21
# Total fractal dimension: 3.6265
#
# Number of clusters: 22
# Total fractal dimension: 3.5898
#
# Number of clusters: 23
# Total fractal dimension: 3.5188
#
# Number of clusters: 24
# Total fractal dimension: 3.4778
#
# Number of clusters: 25
# Total fractal dimension: 3.4246
#
# Number of clusters: 26
# Total fractal dimension: 3.3848
#
# Number of clusters: 27
# Total fractal dimension: 3.3486
#
# Number of clusters: 28
# Total fractal dimension: 3.3034
#
# Number of clusters: 29
# Total fractal dimension: 3.2676
#
# Number of clusters: 30
# Total fractal dimension: 3.2333
#
# Number of clusters: 31
# Total fractal dimension: 3.2016
#
# Number of clusters: 32
# Total fractal dimension: 3.1738
#
# Number of clusters: 33
# Total fractal dimension: 3.1460
#
# Number of clusters: 34
# Total fractal dimension: 3.1096
#
# Number of clusters: 35
# Total fractal dimension: 3.0852
#
# Number of clusters: 36
# Total fractal dimension: 3.0747
#
# Number of clusters: 37
# Total fractal dimension: 3.0391
#
# Number of clusters: 38
# Total fractal dimension: 3.0150
#
# Number of clusters: 39
# Total fractal dimension: 2.9877
#
# Number of clusters: 40
# Total fractal dimension: 2.9778
#
# Number of clusters: 41
# Total fractal dimension: 2.9577
#
# Number of clusters: 42
# Total fractal dimension: 2.9386
#
# Number of clusters: 43
# Total fractal dimension: 2.9189
#
# Number of clusters: 44
# Total fractal dimension: 2.9002
#
# Number of clusters: 45
# Total fractal dimension: 2.8819
#
# Number of clusters: 46
# Total fractal dimension: 2.8640
#
# Number of clusters: 47
# Total fractal dimension: 2.8469
#
# Number of clusters: 48
# Total fractal dimension: 2.8314
#
# Number of clusters: 49
# Total fractal dimension: 2.8161
#
# Number of clusters: 50
# Total fractal dimension: 2.7999
#
# Analyzing word: Draw
#
# Number of clusters: 2
# Total fractal dimension: 16.3785
#
# Number of clusters: 3
# Total fractal dimension: 10.2941
#
# Number of clusters: 4
# Total fractal dimension: 8.1581
#
# Number of clusters: 5
# Total fractal dimension: 6.9851
#
# Number of clusters: 6
# Total fractal dimension: 6.2630
#
# Number of clusters: 7
# Total fractal dimension: 5.7541
#
# Number of clusters: 8
# Total fractal dimension: 5.3769
#
# Number of clusters: 9
# Total fractal dimension: 5.0952
#
# Number of clusters: 10
# Total fractal dimension: 4.8709
#
# Number of clusters: 11
# Total fractal dimension: 4.6605
#
# Number of clusters: 12
# Total fractal dimension: 4.4860
#
# Number of clusters: 13
# Total fractal dimension: 4.3313
#
# Number of clusters: 14
# Total fractal dimension: 4.2286
#
# Number of clusters: 15
# Total fractal dimension: 4.1024
#
# Number of clusters: 16
# Total fractal dimension: 3.9980
#
# Number of clusters: 17
# Total fractal dimension: 3.9389
#
# Number of clusters: 18
# Total fractal dimension: 3.8320
#
# Number of clusters: 19
# ...
#
# Number of clusters: 13
# Total fractal dimension: 4.3307
#
# Number of clusters: 14
# Total fractal dimension: 4.2421
#
# Number of clusters: 15
# Total fractal dimension: 4.1030
#
# Number of clusters: 16
# Total fractal dimension: 3.9995
#
# Number of clusters: 17
# Total fractal dimension: 3.9291
#
# Number of clusters: 18
# Total fractal dimension: 3.8325
#
# Number of clusters: 19
# Total fractal dimension: 3.7593
#
# Number of clusters: 20
# Total fractal dimension: 3.7107
#
# Number of clusters: 21
# Total fractal dimension: 3.6369
#
# Number of clusters: 22
# Total fractal dimension: 3.5776
#
# Number of clusters: 23
# Total fractal dimension: 3.5303
#
# Number of clusters: 24
# Total fractal dimension: 3.4734
#
# Number of clusters: 25
# Total fractal dimension: 3.4225
#
# Number of clusters: 26
# Total fractal dimension: 3.3887
#
# Number of clusters: 27
# Total fractal dimension: 3.3353
#
# Number of clusters: 28
# Total fractal dimension: 3.3016
#
# Number of clusters: 29
# Total fractal dimension: 3.2660
#
# Number of clusters: 30
# Total fractal dimension: 3.2348
#
# Number of clusters: 31
# Total fractal dimension: 3.2007
#
# Number of clusters: 32
# Total fractal dimension: 3.1678
#
# Number of clusters: 33
# Total fractal dimension: 3.1390
#
# Number of clusters: 34
# Total fractal dimension: 3.1112
#
# Number of clusters: 35
# Total fractal dimension: 3.0884
#
# Number of clusters: 36
# Total fractal dimension: 3.0618
#
# Number of clusters: 37
# Total fractal dimension: 3.0484
#
# Number of clusters: 38
# Total fractal dimension: 3.0156
#
# Number of clusters: 39
# Total fractal dimension: 2.9885
#
# Number of clusters: 40
# Total fractal dimension: 2.9782
#
# Number of clusters: 41
# Total fractal dimension: 2.9571
#
# Number of clusters: 42
# Total fractal dimension: 2.9363
#
# Number of clusters: 43
# Total fractal dimension: 2.9162
#
# Number of clusters: 44
# Total fractal dimension: 2.8971
#
# Number of clusters: 45
# Total fractal dimension: 2.8797
#
# Number of clusters: 46
# Total fractal dimension: 2.8619
#
# Number of clusters: 47
# Total fractal dimension: 2.8448
#
# Number of clusters: 48
# Total fractal dimension: 2.8293
#
# Number of clusters: 49
# Total fractal dimension: 2.8128
#
# Number of clusters: 50
# Total fractal dimension: 2.7984
#
# Analyzing word: Send
#
# Number of clusters: 2
# Total fractal dimension: 16.3788
#
# Number of clusters: 3
# Total fractal dimension: 10.2925
#
# Number of clusters: 4
# Total fractal dimension: 8.1294
#
# Number of clusters: 5
# Total fractal dimension: 6.9832
#
# Number of clusters: 6
# Total fractal dimension: 6.2653
#
# Number of clusters: 7
# Total fractal dimension: 5.7545
#
# Number of clusters: 8
# Total fractal dimension: 5.3944
#
# Number of clusters: 9
# Total fractal dimension: 5.0873
#
# Number of clusters: 10
# Total fractal dimension: 4.8932
#
# Number of clusters: 11
# Total fractal dimension: 4.6618
#
# Number of clusters: 12
# Total fractal dimension: 4.4842
#
# Number of clusters: 13
# Total fractal dimension: 4.3319
#
# Number of clusters: 14
# Total fractal dimension: 4.2358
#
# Number of clusters: 15
# Total fractal dimension: 4.1007
#
# Number of clusters: 16
# Total fractal dimension: 4.0151
#
# Number of clusters: 17
# Total fractal dimension: 3.9212
#
# Number of clusters: 18
# Total fractal dimension: 3.8360
#
# Number of clusters: 19
# Total fractal dimension: 3.7594
#
# Number of clusters: 20
# Total fractal dimension: 3.6890
#
# Number of clusters: 21
# Total fractal dimension: 3.6352
#
# Number of clusters: 22
# Total fractal dimension: 3.5713
#
# Number of clusters: 23
# Total fractal dimension: 3.5174
#
# Number of clusters: 24
# Total fractal dimension: 3.4690
#
# Number of clusters: 25
# Total fractal dimension: 3.4234
#
# Number of clusters: 26
# Total fractal dimension: 3.3833
#
# Number of clusters: 27
# Total fractal dimension: 3.3484
#
# Number of clusters: 28
# Total fractal dimension: 3.2990
#
# Number of clusters: 29
# Total fractal dimension: 3.2674
#
# Number of clusters: 30
# Total fractal dimension: 3.2371
#
# Number of clusters: 31
# Total fractal dimension: 3.1993
#
# Number of clusters: 32
# Total fractal dimension: 3.1748
#
# Number of clusters: 33
# Total fractal dimension: 3.1489
#
# Number of clusters: 34
# Total fractal dimension: 3.1155
#
# Number of clusters: 35
# Total fractal dimension: 3.0871
#
# Number of clusters: 36
# Total fractal dimension: 3.0583
#
# Number of clusters: 37
# Total fractal dimension: 3.0414
#
# Number of clusters: 38
# Total fractal dimension: 3.0166
#
# Number of clusters: 39
# Total fractal dimension: 2.9977
#
# Number of clusters: 40
# Total fractal dimension: 2.9731
#
# Number of clusters: 41
# Total fractal dimension: 2.9522
#
# Number of clusters: 42
# Total fractal dimension: 2.9314
#
# Number of clusters: 43
# Total fractal dimension: 2.9122
#
# Number of clusters: 44
# Total fractal dimension: 2.8933
#
# Number of clusters: 45
# Total fractal dimension: 2.8747
#
# Number of clusters: 46
# Total fractal dimension: 2.8573
#
# Number of clusters: 47
# Total fractal dimension: 2.8400
#
# Number of clusters: 48
# Total fractal dimension: 2.8232
#
# Number of clusters: 49
# Total fractal dimension: 2.8081
#
# Number of clusters: 50
# Total fractal dimension: 2.7924
#
# Analyzing word: Drive
#
# Number of clusters: 2
# Total fractal dimension: 16.3784
#
# Number of clusters: 3
# Total fractal dimension: 10.2919
#
# Number of clusters: 4
# Total fractal dimension: 8.1285
#
# Number of clusters: 5
# Total fractal dimension: 6.9907
#
# Number of clusters: 6
# Total fractal dimension: 6.2620
#
# Number of clusters: 7
# Total fractal dimension: 5.7533
#
# Number of clusters: 8
# Total fractal dimension: 5.3777
#
# Number of clusters: 9
# Total fractal dimension: 5.0890
#
# Number of clusters: 10
# Total fractal dimension: 4.8573
#
# Number of clusters: 11
# Total fractal dimension: 4.6436
#
# Number of clusters: 12
# Total fractal dimension: 4.4760
#
# Number of clusters: 13
# Total fractal dimension: 4.3404
#
# Number of clusters: 14
# Total fractal dimension: 4.2191
#
# Number of clusters: 15
# Total fractal dimension: 4.1080
#
# Number of clusters: 16
# Total fractal dimension: 4.0071
#
# Number of clusters: 17
# Total fractal dimension: 3.9142
#
# Number of clusters: 18
# Total fractal dimension: 3.8325
#
# Number of clusters: 19
# Total fractal dimension: 3.7619
#
# Number of clusters: 20
# Total fractal dimension: 3.6891
#
# Number of clusters: 21
# Total fractal dimension: 3.6346
#
# Number of clusters: 22
# Total fractal dimension: 3.5705
#
# Number of clusters: 23
# Total fractal dimension: 3.5173
#
# Number of clusters: 24
# Total fractal dimension: 3.4695
#
# Number of clusters: 25
# Total fractal dimension: 3.4280
#
# Number of clusters: 26
# Total fractal dimension: 3.3851
#
# Number of clusters: 27
# Total fractal dimension: 3.3452
#
# Number of clusters: 28
# Total fractal dimension: 3.3074
#
# Number of clusters: 29
# Total fractal dimension: 3.2691
#
# Number of clusters: 30
# Total fractal dimension: 3.2413
#
# Number of clusters: 31
# Total fractal dimension: 3.2019
#
# Number of clusters: 32
# Total fractal dimension: 3.1745
#
# Number of clusters: 33
# Total fractal dimension: 3.1531
#
# Number of clusters: 34
# Total fractal dimension: 3.1257
#
# Number of clusters: 35
# Total fractal dimension: 3.0902
#
# Number of clusters: 36
# Total fractal dimension: 3.0621
#
# Number of clusters: 37
# Total fractal dimension: 3.0431
#
# Number of clusters: 38
# Total fractal dimension: 3.0143
#
# Number of clusters: 39
# Total fractal dimension: 2.9958
#
# Number of clusters: 40
# Total fractal dimension: 2.9725
#
# Number of clusters: 41
# Total fractal dimension: 2.9513
#
# Number of clusters: 42
# Total fractal dimension: 2.9311
#
# Number of clusters: 43
# Total fractal dimension: 2.9124
#
# Number of clusters: 44
# Total fractal dimension: 2.8942
#
# Number of clusters: 45
# Total fractal dimension: 2.8774
#
# Number of clusters: 46
# Total fractal dimension: 2.8590
#
# Number of clusters: 47
# Total fractal dimension: 2.8421
#
# Number of clusters: 48
# Total fractal dimension: 2.8249
#
# Number of clusters: 49
# Total fractal dimension: 2.8089
#
# Number of clusters: 50
# Total fractal dimension: 2.7931
#
# Analyzing word: Throw
#
# Number of clusters: 2
# Total fractal dimension: 16.3781
#
# Number of clusters: 3
# Total fractal dimension: 10.2892
#
# Number of clusters: 4
# Total fractal dimension: 8.1279
#
# Number of clusters: 5
# Total fractal dimension: 6.9836
#
# Number of clusters: 6
# Total fractal dimension: 6.2730
#
# Number of clusters: 7
# Total fractal dimension: 5.7637
#
# Number of clusters: 8
# Total fractal dimension: 5.3755
#
# Number of clusters: 9
# Total fractal dimension: 5.0804
#
# Number of clusters: 10
# Total fractal dimension: 4.8699
#
# Number of clusters: 11
# Total fractal dimension: 4.6541
#
# Number of clusters: 12
# Total fractal dimension: 4.5049
#
# Number of clusters: 13
# Total fractal dimension: 4.3399
#
# Number of clusters: 14
# Total fractal dimension: 4.2489
#
# Number of clusters: 15
# Total fractal dimension: 4.1001
#
# Number of clusters: 16
# Total fractal dimension: 4.0103
#
# Number of clusters: 17
# Total fractal dimension: 3.9165
#
# Number of clusters: 18
# Total fractal dimension: 3.8293
#
# Number of clusters: 19
# Total fractal dimension: 3.7546
#
# Number of clusters: 20
# Total fractal dimension: 3.6902
#
# Number of clusters: 21
# Total fractal dimension: 3.6289
#
# Number of clusters: 22
# Total fractal dimension: 3.5771
#
# Number of clusters: 23
# Total fractal dimension: 3.5275
#
# Number of clusters: 24
# Total fractal dimension: 3.4728
#
# Number of clusters: 25
# Total fractal dimension: 3.4286
#
# Number of clusters: 26
# Total fractal dimension: 3.3822
#
# Number of clusters: 27
# Total fractal dimension: 3.3527
#
# Number of clusters: 28
# Total fractal dimension: 3.3004
#
# Number of clusters: 29
# Total fractal dimension: 3.2677
#
# Number of clusters: 30
# Total fractal dimension: 3.2346
#
# Number of clusters: 31
# Total fractal dimension: 3.2025
#
# Number of clusters: 32
# Total fractal dimension: 3.1711
#
# Number of clusters: 33
# Total fractal dimension: 3.1422
#
# Number of clusters: 34
# Total fractal dimension: 3.1136
#
# Number of clusters: 35
# Total fractal dimension: 3.0909
#
# Number of clusters: 36
# Total fractal dimension: 3.0633
#
# Number of clusters: 37
# Total fractal dimension: 3.0338
#
# Number of clusters: 38
# Total fractal dimension: 3.0148
#
# Number of clusters: 39
# Total fractal dimension: 2.9932
#
# Number of clusters: 40
# Total fractal dimension: 2.9695
#
# Number of clusters: 41
# Total fractal dimension: 2.9498
#
# Number of clusters: 42
# Total fractal dimension: 2.9306
#
# Number of clusters: 43
# Total fractal dimension: 2.9118
#
# Number of clusters: 44
# Total fractal dimension: 2.8933
#
# Number of clusters: 45
# Total fractal dimension: 2.8762
#
# Number of clusters: 46
# Total fractal dimension: 2.8586
#
# Number of clusters: 47
# Total fractal dimension: 2.8424
#
# Number of clusters: 48
# Total fractal dimension: 2.8257
#
# Number of clusters: 49
# Total fractal dimension: 2.8094
#
# Number of clusters: 50
# Total fractal dimension: 2.7940
#
# Analyzing word: Read
#
# Number of clusters: 2
# Total fractal dimension: 16.3786
#
# Number of clusters: 3
# Total fractal dimension: 10.2932
#
# Number of clusters: 4
# Total fractal dimension: 8.1293
#
# Number of clusters: 5
# Total fractal dimension: 6.9881
#
# Number of clusters: 6
# Total fractal dimension: 6.2611
#
# Number of clusters: 7
# Total fractal dimension: 5.7637
#
# Number of clusters: 8
# Total fractal dimension: 5.3765
#
# Number of clusters: 9
# Total fractal dimension: 5.0793
#
# Number of clusters: 10
# Total fractal dimension: 4.8621
#
# Number of clusters: 11
# Total fractal dimension: 4.6500
#
# Number of clusters: 12
# Total fractal dimension: 4.4916
#
# Number of clusters: 13
# Total fractal dimension: 4.3413
#
# Number of clusters: 14
# Total fractal dimension: 4.2255
#
# Number of clusters: 15
# Total fractal dimension: 4.0979
#
# Number of clusters: 16
# Total fractal dimension: 4.0052
#
# Number of clusters: 17
# Total fractal dimension: 3.9239
#
# Number of clusters: 18
# Total fractal dimension: 3.8288
#
# Number of clusters: 19
# Total fractal dimension: 3.7581
#
# Number of clusters: 20
# Total fractal dimension: 3.6911
#
# Number of clusters: 21
# Total fractal dimension: 3.6341
#
# Number of clusters: 22
# Total fractal dimension: 3.5722
#
# Number of clusters: 23
# Total fractal dimension: 3.5187
#
# Number of clusters: 24
# Total fractal dimension: 3.4708
#
# Number of clusters: 25
# Total fractal dimension: 3.4321
#
# Number of clusters: 26
# Total fractal dimension: 3.3796
#
# Number of clusters: 27
# Total fractal dimension: 3.3440
#
# Number of clusters: 28
# Total fractal dimension: 3.3003
#
# Number of clusters: 29
# Total fractal dimension: 3.2655
#
# Number of clusters: 30
# Total fractal dimension: 3.2364
#
# Number of clusters: 31
# Total fractal dimension: 3.1968
#
# Number of clusters: 32
# Total fractal dimension: 3.1692
#
# Number of clusters: 33
# Total fractal dimension: 3.1401
#
# Number of clusters: 34
# Total fractal dimension: 3.1158
#
# Number of clusters: 35
# Total fractal dimension: 3.0893
#
# Number of clusters: 36
# Total fractal dimension: 3.0611
#
# Number of clusters: 37
# Total fractal dimension: 3.0542
#
# Number of clusters: 38
# Total fractal dimension: 3.0129
#
# Number of clusters: 39
# Total fractal dimension: 2.9937
#
# Number of clusters: 40
# Total fractal dimension: 2.9704
#
# Number of clusters: 41
# Total fractal dimension: 2.9490
#
# Number of clusters: 42
# Total fractal dimension: 2.9299
#
# Number of clusters: 43
# Total fractal dimension: 2.9113
#
# Number of clusters: 44
# Total fractal dimension: 2.8926
#
# Number of clusters: 45
# Total fractal dimension: 2.8754
#
# Number of clusters: 46
# Total fractal dimension: 2.8575
#
# Number of clusters: 47
# Total fractal dimension: 2.8411
#
# Number of clusters: 48
# Total fractal dimension: 2.8247
#
# Number of clusters: 49
# Total fractal dimension: 2.8096
#
# Number of clusters: 50
# Total fractal dimension: 2.7937
#
# Analyzing word: Walk
#
# Number of clusters: 2
# Total fractal dimension: 16.3781
#
# Number of clusters: 3
# Total fractal dimension: 10.2896
#
# Number of clusters: 4
# Total fractal dimension: 8.1532
#
# Number of clusters: 5
# Total fractal dimension: 6.9845
#
# Number of clusters: 6
# Total fractal dimension: 6.2614
#
# Number of clusters: 7
# Total fractal dimension: 5.7541
#
# Number of clusters: 8
# Total fractal dimension: 5.3835
#
# Number of clusters: 9
# Total fractal dimension: 5.0886
#
# Number of clusters: 10
# Total fractal dimension: 4.8633
#
# Number of clusters: 11
# Total fractal dimension: 4.6693
#
# Number of clusters: 12
# Total fractal dimension: 4.4983
#
# Number of clusters: 13
# Total fractal dimension: 4.3353
#
# Number of clusters: 14
# Total fractal dimension: 4.2085
#
# Number of clusters: 15
# Total fractal dimension: 4.0985
#
# Number of clusters: 16
# Total fractal dimension: 3.9964
#
# Number of clusters: 17
# Total fractal dimension: 3.9383
#
# Number of clusters: 18
# Total fractal dimension: 3.8322
#
# Number of clusters: 19
# Total fractal dimension: 3.7594
#
# Number of clusters: 20
# Total fractal dimension: 3.6917
#
# Number of clusters: 21
# Total fractal dimension: 3.6314
#
# Number of clusters: 22
# Total fractal dimension: 3.5732
#
# Number of clusters: 23
# Total fractal dimension: 3.5237
#
# Number of clusters: 24
# Total fractal dimension: 3.4763
#
# Number of clusters: 25
# Total fractal dimension: 3.4269
#
# Number of clusters: 26
# Total fractal dimension: 3.3831
#
# Number of clusters: 27
# Total fractal dimension: 3.3420
#
# Number of clusters: 28
# Total fractal dimension: 3.3048
#
# Number of clusters: 29
# Total fractal dimension: 3.2671
#
# Number of clusters: 30
# Total fractal dimension: 3.2325
#
# Number of clusters: 31
# Total fractal dimension: 3.1997
#
# Number of clusters: 32
# Total fractal dimension: 3.1785
#
# Number of clusters: 33
# Total fractal dimension: 3.1403
#
# Number of clusters: 34
# Total fractal dimension: 3.1205
#
# Number of clusters: 35
# Total fractal dimension: 3.1023
#
# Number of clusters: 36
# Total fractal dimension: 3.0586
#
# Number of clusters: 37
# Total fractal dimension: 3.0364
#
# Number of clusters: 38
# Total fractal dimension: 3.0211
#
# Number of clusters: 39
# Total fractal dimension: 2.9897
#
# Number of clusters: 40
# Total fractal dimension: 2.9788
#
# Number of clusters: 41
# Total fractal dimension: 2.9590
#
# Number of clusters: 42
# Total fractal dimension: 2.9397
#
# Number of clusters: 43
# Total fractal dimension: 2.9193
#
# Number of clusters: 44
# Total fractal dimension: 2.8999
#
# Number of clusters: 45
# Total fractal dimension: 2.8811
#
# Number of clusters: 46
# Total fractal dimension: 2.8633
#
# Number of clusters: 47
# Total fractal dimension: 2.8456
#
# Number of clusters: 48
# Total fractal dimension: 2.8288
#
# Number of clusters: 49
# Total fractal dimension: 2.8129
#
# Number of clusters: 50
# Total fractal dimension: 2.7979
# time: 2h 40min 54s (started: 2024-11-10 17:40:44 +00:00)

# %%
#Summarized fractal analysis for each word, fractal value calculated for each word in the list.

import numpy as np
import faiss
import matplotlib.pyplot as plt
import requests
import io

print(f"Total number of words: {len(word_embeddings)}")
print(f"Dimension of each word vector: {vector_size}")

# Create FAISS index
print("Creating FAISS index...")
index = faiss.IndexFlatL2(vector_size)
index.add(np.array(list(word_embeddings.values())))

def correlation_dimension_faiss(data, max_radius, num_radii=20, k=100):
    n_samples, n_features = data.shape
    data = data.astype(np.float32)

    radii = np.logspace(-1, np.log10(max_radius), num_radii)
    correlation_sum = np.zeros(num_radii)

    distances, _ = index.search(data, k)

    for i, r in enumerate(radii):
        count_within_radius = np.sum(distances < r**2, axis=1) - 1
        total_count = np.sum(count_within_radius)
        correlation_sum[i] = max(total_count / (n_samples * (n_samples - 1)), 1e-10)

    return radii, correlation_sum

def estimate_fractal_dimension(radii, correlation_sum):
    valid_indices = correlation_sum > 0
    log_radii = np.log(radii[valid_indices])
    log_correlation_sum = np.log(correlation_sum[valid_indices])

    if len(log_radii) < 2:
        return np.nan

    coeffs = np.polyfit(log_radii, log_correlation_sum, deg=1)
    return coeffs[0]

# List of words to analyze
words_to_analyze = [
    "Set", "Run", "Go", "Take", "Get", "Make", "Put", "Stand", "Hold", "Turn",
    "Break", "Fall", "Cut", "Pass", "Bring", "Do", "Catch", "Draw", "Leave", "Keep",
    "Pay", "Build", "Lead", "Raise", "Move", "Close", "Meet", "Reach", "Send", "Drive",
    "Throw", "Read", "Walk"
]

fractal_dimensions = {}

for word in words_to_analyze:
    if word.lower() in word_embeddings:
        print(f"\nAnalyzing word: {word}")

        # Find 10,000 closest words
        query_vector = word_embeddings[word.lower()].reshape(1, -1)
        _, indices = index.search(query_vector, 10000)

        closest_words_embeddings = np.array([list(word_embeddings.values())[i] for i in indices[0]])

        max_radius = np.sqrt(vector_size)  # Maximum possible distance in the feature space
        radii, correlation_sum = correlation_dimension_faiss(closest_words_embeddings, max_radius)

        fractal_dim = estimate_fractal_dimension(radii, correlation_sum)
        fractal_dimensions[word] = fractal_dim

        print(f"Estimated fractal dimension for '{word}': {fractal_dim:.4f}")

        # Plot results
        plt.figure(figsize=(10, 6))
        plt.loglog(radii, correlation_sum, 'bo-')
        plt.xlabel('Radius (r)')
        plt.ylabel('Correlation Sum C(r)')
        plt.title(f'Correlation Dimension Analysis for "{word}"')
        plt.grid(True)
        plt.savefig(f'{word}_correlation_dimension.png')
        plt.close()
    else:
        print(f"\nWord '{word}' not found in the embeddings.")


# Calculate and print average fractal dimension
avg_fractal_dim = np.mean(list(fractal_dimensions.values()))
print(f"\nAverage Fractal Dimension: {avg_fractal_dim:.4f}")

# Plot histogram of fractal dimensions
plt.figure(figsize=(10, 6))
plt.hist(list(fractal_dimensions.values()), bins=10, edgecolor='black')
plt.xlabel('Fractal Dimension')
plt.ylabel('Frequency')
plt.title('Distribution of Fractal Dimensions')
plt.axvline(avg_fractal_dim, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {avg_fractal_dim:.4f}')
plt.legend()
plt.savefig('fractal_dimension_distribution.png')
plt.close()
# Out:
# Total number of words: 111051
# Dimension of each word vector: 300
# Creating FAISS index...
#
# Analyzing word: Set
# Estimated fractal dimension for 'Set': 4.8151
#
# Analyzing word: Run
# Estimated fractal dimension for 'Run': 4.8151
#
# Analyzing word: Go
# Estimated fractal dimension for 'Go': 4.8180
#
# Analyzing word: Take
# Estimated fractal dimension for 'Take': 4.8174
#
# Analyzing word: Get
# Estimated fractal dimension for 'Get': 4.8164
#
# Analyzing word: Make
# Estimated fractal dimension for 'Make': 4.8176
#
# Analyzing word: Put
# Estimated fractal dimension for 'Put': 4.8163
#
# Analyzing word: Stand
# Estimated fractal dimension for 'Stand': 4.8183
#
# Analyzing word: Hold
# Estimated fractal dimension for 'Hold': 4.8164
#
# Analyzing word: Turn
# Estimated fractal dimension for 'Turn': 4.8175
#
# Analyzing word: Break
# Estimated fractal dimension for 'Break': 4.8190
#
# Analyzing word: Fall
# Estimated fractal dimension for 'Fall': 4.8194
#
# Analyzing word: Cut
# Estimated fractal dimension for 'Cut': 4.8157
#
# Analyzing word: Pass
# Estimated fractal dimension for 'Pass': 4.8184
#
# Analyzing word: Bring
# Estimated fractal dimension for 'Bring': 4.8175
#
# Analyzing word: Do
# Estimated fractal dimension for 'Do': 4.8170
#
# Analyzing word: Catch
# Estimated fractal dimension for 'Catch': 4.8140
#
# Analyzing word: Draw
# Estimated fractal dimension for 'Draw': 4.8174
#
# Analyzing word: Leave
# Estimated fractal dimension for 'Leave': 4.8178
#
# Analyzing word: Keep
# Estimated fractal dimension for 'Keep': 4.8154
#
# Analyzing word: Pay
# Estimated fractal dimension for 'Pay': 4.8127
#
# Analyzing word: Build
# Estimated fractal dimension for 'Build': 4.8151
#
# Analyzing word: Lead
# Estimated fractal dimension for 'Lead': 4.8189
#
# Analyzing word: Raise
# Estimated fractal dimension for 'Raise': 4.8147
#
# Analyzing word: Move
# Estimated fractal dimension for 'Move': 4.8162
#
# Analyzing word: Close
# Estimated fractal dimension for 'Close': 4.8199
#
# Analyzing word: Meet
# Estimated fractal dimension for 'Meet': 4.8168
#
# Analyzing word: Reach
# Estimated fractal dimension for 'Reach': 4.8159
#
# Analyzing word: Send
# Estimated fractal dimension for 'Send': 4.8147
#
# Analyzing word: Drive
# Estimated fractal dimension for 'Drive': 4.8159
#
# Analyzing word: Throw
# Estimated fractal dimension for 'Throw': 4.8143
#
# Analyzing word: Read
# Estimated fractal dimension for 'Read': 4.8174
#
# Analyzing word: Walk
# Estimated fractal dimension for 'Walk': 4.8149
#
# Average Fractal Dimension: 4.8166
# time: 24min 19s (started: 2024-11-10 20:21:39 +00:00)

# %%
# List of words to analyze
words_to_analyze = ["mole", "curtsey", "burrow", "convect"
]

fractal_dimensions = {}

for word in words_to_analyze:
    if word.lower() in word_embeddings:
        print(f"\nAnalyzing word: {word}")

        # Find 10,000 closest words
        query_vector = word_embeddings[word.lower()].reshape(1, -1)
        _, indices = index.search(query_vector, 10000)

        closest_words_embeddings = np.array([list(word_embeddings.values())[i] for i in indices[0]])

        max_radius = np.sqrt(vector_size)  # Maximum possible distance in the feature space
        radii, correlation_sum = correlation_dimension_faiss(closest_words_embeddings, max_radius)

        fractal_dim = estimate_fractal_dimension(radii, correlation_sum)
        fractal_dimensions[word] = fractal_dim

        print(f"Estimated fractal dimension for '{word}': {fractal_dim:.4f}")

        # Plot results
        plt.figure(figsize=(10, 6))
        plt.loglog(radii, correlation_sum, 'bo-')
        plt.xlabel('Radius (r)')
        plt.ylabel('Correlation Sum C(r)')
        plt.title(f'Correlation Dimension Analysis for "{word}"')
        plt.grid(True)
        plt.savefig(f'{word}_correlation_dimension.png')
        plt.close()
    else:
        print(f"\nWord '{word}' not found in the embeddings.")


# Calculate and print average fractal dimension
avg_fractal_dim = np.mean(list(fractal_dimensions.values()))
print(f"\nAverage Fractal Dimension: {avg_fractal_dim:.4f}")

# Plot histogram of fractal dimensions
plt.figure(figsize=(10, 6))
plt.hist(list(fractal_dimensions.values()), bins=10, edgecolor='black')
plt.xlabel('Fractal Dimension')
plt.ylabel('Frequency')
plt.title('Distribution of Fractal Dimensions')
plt.axvline(avg_fractal_dim, color='r', linestyle='dashed', linewidth=2, label=f'Mean: {avg_fractal_dim:.4f}')
plt.legend()
plt.savefig('fractal_dimension_distribution2.png')
plt.close()
# Out:
# Analyzing word: mole
# Estimated fractal dimension for 'mole': 4.8150
#
# Analyzing word: curtsey
# Estimated fractal dimension for 'curtsey': 4.8187
#
# Analyzing word: burrow
# Estimated fractal dimension for 'burrow': 4.8099
#
# Word 'convect' not found in the embeddings.
#
# Average Fractal Dimension: 4.8146
# time: 2min 13s (started: 2024-11-10 21:00:42 +00:00)

# %%
# %ls
# Out:
# average_fractal_dimension.png        Make_correlation_dimension.png
# Break_correlation_dimension.png      Make_fractal_dimension.png
# Break_fractal_dimension.png          Meet_correlation_dimension.png
# Bring_correlation_dimension.png      Meet_fractal_dimension.png
# Bring_fractal_dimension.png          mole_correlation_dimension.png
# Build_correlation_dimension.png      Move_correlation_dimension.png
# Build_fractal_dimension.png          Move_fractal_dimension.png
# burrow_correlation_dimension.png     Pass_correlation_dimension.png
# Catch_correlation_dimension.png      Pass_fractal_dimension.png
# Catch_fractal_dimension.png          Pay_correlation_dimension.png
# Close_correlation_dimension.png      Pay_fractal_dimension.png
# Close_fractal_dimension.png          Put_correlation_dimension.png
# curtsey_correlation_dimension.png    Put_fractal_dimension.png
# Cut_correlation_dimension.png        Raise_correlation_dimension.png
# Cut_fractal_dimension.png            Raise_fractal_dimension.png
# Do_correlation_dimension.png         Reach_correlation_dimension.png
# Do_fractal_dimension.png             Reach_fractal_dimension.png
# Draw_correlation_dimension.png       Read_correlation_dimension.png
# Draw_fractal_dimension.png           Read_fractal_dimension.png
# Drive_correlation_dimension.png      Run_correlation_dimension.png
# Drive_fractal_dimension.png          Run_fractal_dimension.png
# Fall_correlation_dimension.png       sample_data/
# Fall_fractal_dimension.png           Send_correlation_dimension.png
# fractal_dimension_distribution2.png  Send_fractal_dimension.png
# fractal_dimension_distribution.png   Set_correlation_dimension.png
# Get_correlation_dimension.png        Set_fractal_dimension.png
# Get_fractal_dimension.png            Stand_correlation_dimension.png
# Go_correlation_dimension.png         Stand_fractal_dimension.png
# Go_fractal_dimension.png             Take_correlation_dimension.png
# Hold_correlation_dimension.png       Take_fractal_dimension.png
# Hold_fractal_dimension.png           Throw_correlation_dimension.png
# Keep_correlation_dimension.png       Throw_fractal_dimension.png
# Keep_fractal_dimension.png           Turn_correlation_dimension.png
# Lead_correlation_dimension.png       Turn_fractal_dimension.png
# Lead_fractal_dimension.png           Walk_correlation_dimension.png
# Leave_correlation_dimension.png      Walk_fractal_dimension.png
# Leave_fractal_dimension.png
# time: 110 ms (started: 2024-11-10 21:03:03 +00:00)
